# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

import re
import math
import numpy as np

# %%
NEWS_FILE = 'data/news_reuters.csv'

# %%
col_names = ['code','name','date','headline','article','importance']
news = pd.read_csv(NEWS_FILE,names=col_names)

# %%
news
# Out:
#         code          name      date  \
# 0      GOOGL  Alphabet Inc  20181210
# 1      GOOGL  Alphabet Inc  20181210
# 2      GOOGL  Alphabet Inc  20181210
# 3      GOOGL  Alphabet Inc  20181210
# 4      GOOGL  Alphabet Inc  20181210
# 5      GOOGL  Alphabet Inc  20181210
# 6      GOOGL  Alphabet Inc  20181210
# 7      GOOGL  Alphabet Inc  20181210
# 8      GOOGL  Alphabet Inc  20181205
# 9      GOOGL  Alphabet Inc  20181205
# 10     GOOGL  Alphabet Inc  20181204
# 11     GOOGL  Alphabet Inc  20181204
# 12     GOOGL  Alphabet Inc  20181202
# 13     GOOGL  Alphabet Inc  20181202
# 14     GOOGL  Alphabet Inc  20181130
# 15     GOOGL  Alphabet Inc  20181129
# 16     GOOGL  Alphabet Inc  20181128
# 17     GOOGL  Alphabet Inc  20181128
# 18     GOOGL  Alphabet Inc  20181128
# 19     GOOGL  Alphabet Inc  20181128
# 20     GOOGL  Alphabet Inc  20181127
# 21     GOOGL  Alphabet Inc  20181127
# 22     GOOGL  Alphabet Inc  20181127
# 23     GOOGL  Alphabet Inc  20181127
# 24     GOOGL  Alphabet Inc  20181127
# 25     GOOGL  Alphabet Inc  20181126
# 26     GOOGL  Alphabet Inc  20181123
# 27     GOOGL  Alphabet Inc  20181123
# 28     GOOGL  Alphabet Inc  20181119
# 29     GOOGL  Alphabet Inc  20181116
# ...      ...           ...       ...
# 27087    PEP   Pepsico Inc  20180426
# 27088    PEP   Pepsico Inc  20180426
# 27089    PEP   Pepsico Inc  20180426
# 27090    PEP   Pepsico Inc  20180426
# 27091    PEP   Pepsico Inc  20180323
# 27092    PEP   Pepsico Inc  20180320
# 27093    PEP   Pepsico Inc  20180316
# 27094    PEP   Pepsico Inc  20180305
# 27095    PEP   Pepsico Inc  20180214
# 27096    PEP   Pepsico Inc  20180214
# 27097    PEP   Pepsico Inc  20180214
# 27098    PEP   Pepsico Inc  20180213
# 27099    PEP   Pepsico Inc  20180213
# 27100    PEP   Pepsico Inc  20180213
# 27101    PEP   Pepsico Inc  20180213
# 27102    PEP   Pepsico Inc  20180213
# 27103    PEP   Pepsico Inc  20180213
# 27104    PEP   Pepsico Inc  20180206
# 27105    PEP   Pepsico Inc  20180131
# 27106    PEP   Pepsico Inc  20180131
# 27107    PEP   Pepsico Inc  20180129
# 27108    PEP   Pepsico Inc  20180125
# 27109    PEP   Pepsico Inc  20180124
# 27110    PEP   Pepsico Inc  20180124
# 27111    PEP   Pepsico Inc  20180124
# 27112    PEP   Pepsico Inc  20180122
# 27113    PEP   Pepsico Inc  20180122
# 27114    PEP   Pepsico Inc  20180118
# 27115    PEP   Pepsico Inc  20180118
# 27116    PEP   Pepsico Inc  20180117
#
#                                                 headline  \
# 0      Google CEO defends 'integrity' of products ahe...
# 1      Google CEO defends 'integrity' of products ahe...
# 2      Google+ shutdown speeds up  new privacy bug af...
# 3      Google+ shutdown speeds up  new privacy bug af...
# 4      Deep losses leave Big Tech with small earnings...
# 5      GRAPHIC-Deep losses leave Big Tech with small ...
# 6      Australian watchdog wants a regulator for domi...
# 7      UPDATE 3-Australian watchdog wants a regulator...
# 8      Waymo unveils self-driving taxi service in Ari...
# 9      FOCUS-Waymo unveils self-driving taxi service ...
# 10     Alphabet's Wing drone delivery business to tak...
# 11     Alphabet's Wing drone delivery business to tak...
# 12     Google CEO hearing in U.S. House likely to be ...
# 13     Google CEO hearing in U.S. House likely to be ...
# 14     Does Google harm local search rivals? EU antit...
# 15     Indonesia's Go-Jek starts trial launch in Sing...
# 16     U.S. House panel sets Google CEO hearing for D...
# 17     Amazon launches machine learning chip  taking ...
# 18     YouTube shifts to make new exclusive shows  mo...
# 19     UPDATE 2-YouTube shifts to make new exclusive ...
# 20     YouTube shifts to make new exclusive shows  mo...
# 21      Google employees push to stop Project Dragonfly
# 22     RPT-FOCUS-Fearful of bias  Google blocks gende...
# 23     Fearful of bias  Google blocks gender-based pr...
# 24     FOCUS-Fearful of bias  Google blocks gender-ba...
# 25     UPDATE 1-Logitech ends negotiations to acquire...
# 26     Exclusive: A10 Networks explores potential sal...
# 27     EXCLUSIVE-A10 Networks explores potential sale...
# 28     Google-Temasek study sees $240 bln Southeast A...
# 29     Alphabet unit halts glucose-detecting contact ...
# ...                                                  ...
# 27087  Pepsi tops estimates  promises more investment...
# 27088  UPDATE 4-Pepsi tops estimates  promises more i...
# 27089  BRIEF-Pepsico CFO Johnston Says Rising Costs F...
# 27090                   BRIEF-PepsiCo Q1 Core EPS $0.96
# 27091  BRIEF-India's Varun Beverages Concludes Pepsic...
# 27092  China's Tingyi net profit climbs 57 pct  endin...
# 27093  BRIEF-Pepsico Says CEO Indra Nooyi's Total Com...
# 27094  BRIEF-Bundaberg Brewed Drinks And Pepsi Announ...
# 27095  RPT-FOCUS-Sime Darby's Africa ambitions stall ...
# 27096  Sime Darby's Africa ambitions stall pending ne...
# 27097  FOCUS-Sime Darby's Africa ambitions stall pend...
# 27098  PepsiCo tops sales estimates as strong snack b...
# 27099  UPDATE 2-PepsiCo tops sales estimates as stron...
# 27100  BRIEF-Pepsico Says North American Beverage Seg...
# 27101  BRIEF-PepsiCo Reports Quarterly Core EPS of $1...
# 27102  PepsiCo revenue tops Wall St estimates in four...
# 27103  BRIEF-PepsiCo Reports Quarterly Net Revenue of...
# 27104  BRIEF-Pepsico Sets Quarterly Dividend Of $0.80...
# 27105  BRIEF-Britvic Says Q1 Revenue Up 3.3 Pct To 33...
# 27106                UK's Britvic Q1 revenue up 3.3 pct
# 27107  UPDATE 5-Coffee meets 7UP in Keurig  Dr Pepper...
# 27108  BRIEF-Pepsico  NHL And NHLPA Ink Multi-Year No...
# 27109  BRIEF-Unifi Elects Pepsico North America CEO A...
# 27110  PepsiCo cuts ties with palm oil supplier over ...
# 27097  * New rules expected by November on planting i...     normal
# 27098  PepsiCo Inc's  sales topped Wall Street foreca...   topStory
# 27099  Feb 13 PepsiCo Inc's sales topped Wall Street ...     normal
# 27100  * PEPSICO INC SAYS GAINED MARKET SHARE IN SALT...     normal
# 27101  * Q4 EARNINGS PER SHARE VIEW $1.30 -- THOMSON ...     normal
# 27102  Feb 13 PepsiCo Inc's sales topped Wall Street ...     normal
# 27103  * QUARTERLY NET REVENUE $19 526 MILLION VERSUS...     normal
# 27104  * SETS QUARTERLY DIVIDEND OF $0.805 PER SHARE ...   topStory
# 27105  * Q1 ‍CARBONATES REVENUE INCREASED 4.9%  DRIVE...   topStory
# 27106  Jan 31 British soft drinks company Britvic Plc...     normal
# 27107  * Deal is about scale  distribution  brands - ...     normal
# 27108  * PEPSICO  NHL AND NHLPA INK MULTI-YEAR NORTH ...   topStory
# 27109  * UNIFI ELECTS PEPSICO NORTH AMERICA CEO ALBER...   topStory
# 27110  KUALA LUMPUR (Thomson Reuters Foundation) - Fo...     normal
# 27111  KUALA LUMPUR  Jan 24 (Thomson Reuters Foundati...     normal
# 27112  PRAGUE Czech soft drinks maker Karlovarske min...   topStory
# 27113  PRAGUE  Jan 22 Czech soft drinks maker Karlova...     normal
# 27114  MOSCOW Russia's state food safety watchdog wil...   topStory
# 27115  MOSCOW  Jan 18 Russia's state food safety watc...     normal
# 27116  * SAYS APPROVED TO BUY FRANCHISEE RIGHTS FOR P...   topStory
#
# [27117 rows x 6 columns]

# %%
# 清洗数据(词性还原)
def clean_news(news_raws):
    lemma=WordNetLemmatizer()
    news_rows=[]
    for i in range(0,len(news_raws)):
        news=str(news_raws[i])
        news=re.sub('[^a-zA-Z]', ' ',news) 
        news=[lemma.lemmatize(w) for w in word_tokenize(str(news).lower())]  # 词性还原
        news=' '.join(news)
        news_rows.append(news)
    return news_rows

# %%
news['text'] = clean_news(news['headline']+news['article'])

# %%
vectorizer = TfidfVectorizer(stop_words='english')
vectorizer.fit(news['text'] )
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
word=vectorizer.get_feature_names()

# %%
def remove_deplicates(news_file,rad=10,threshold = 0.9):
    dp_list = set()
    tops = news.loc[news['importance']=='topStory']
    for index in tops.index:
        top = list()
        top.append(str(news['text'].loc[index]))
        li = list(range(index-rad,index+rad+1))
        win = [ str(item) for item in news['text'].loc[li]]
        top = vectorizer.transform(top).toarray()[0]
        win = vectorizer.transform(win).toarray()
        for i in range(len(win)):
            cur = win[i]
            up = np.dot(top,cur)
            down = math.sqrt(np.dot(top,top))*math.sqrt(np.dot(cur ,cur))
            if down == 0 :
                continue
            sim = up/down
            if sim > threshold and rad!=i:
                dp_list.add(index-rad+i)
    return dp_list

# %%
dp_list = remove_deplicates(news)

# %%
news2 = news.drop(list(dp_list))

# %%
news2 = news2.drop(['name','date','headline','article'],axis=1)
# Out:
#   File "<ipython-input-27-6e7093485322>", line 1
#     news2 = news2.drop(['name','date','headline','article'].axis=1)
#                       ^
# SyntaxError: keyword can't be an expression
